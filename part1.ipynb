# %% [markdown]
# # Header

# %%
from templates import info_box
from setup import load_styles, load_styles2
load_styles()
load_styles2()
# Out:
#     <style>
#     .info-box {
#         border: 2px solid #28a745;
#         border-radius: 8px;
#         padding: 20px;
#         margin: 10px 0;
#         background-color: #f8fff9;
#         position: relative;
#         max-width: 100%;
#         box-sizing: border-box;
#         color: #155724;
#         font-size: 1.1em;
#         line-height: 1.5;
#     }
#     .info-box-badge {
#         position: absolute;
#         top: -12px;
#         left: 15px;
#         background-color: #28a745;
#         color: white;
#         width: 24px;
#         height: 24px;
#         border-radius: 50%;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         font-family: serif;
#         font-weight: bold;
#         font-style: italic;
#         font-size: 1rem;
#     }
#     .next-button-container {
#         text-align: center;
#         margin-top: 20px;
#     }
#     .next-button {
#         display: inline-block;
# ...

# %%
# A quick test script for your Python environment
import sys

def test_environment():
    print("--- Python Test Output ---")
    
    # 1. Basic Math
    result = (10 * 5) + 2
    print(f"Math Check: (10 * 5) + 2 = {result}")

    # 2. System Version
    print(f"Python Version: {sys.version.split()[0]}")

    # 3. Loops and Lists
    fruits = ["Apple", "Banana", "Cherry"]
    print("Looping through a list:")
    for fruit in fruits:
        print(f" - Found: {fruit}")

    print("--------------------------")
    print("Test Complete: Everything is running smoothly!")

# Execute the function
test_environment()
# Out:
# --- Python Test Output ---
# Math Check: (10 * 5) + 2 = 52
# Python Version: 3.12.7
# Looping through a list:
#  - Found: Apple
#  - Found: Banana
#  - Found: Cherry
# --------------------------
# Test Complete: Everything is running smoothly!

# %% [markdown]
# <div style="
#     border: 2px solid #28a745;
#     border-radius: 8px;
#     padding: 20px;
#     margin: 10px 0;
#     background-color: #f8fff9;
#     position: relative;
#     max-width: 100%;
#     box-sizing: border-box;
# ">
#     <div style="
#         position: absolute;
#         top: -12px;
#         left: 15px;
#         background-color: #28a745;
#         color: white;
#         width: 24px;
#         height: 24px;
#         border-radius: 50%;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         font-family: serif;
#         font-weight: bold;
#         font-style: italic;
#     ">
#         i
#     </div>
#     <div style="color: #155724; font-size: 1.1em; line-height: 1.5;">
#         <b>Information Title</b><br>
#         Your story text or additional context goes here. This space is padded so your
#         words won't feel cramped against the border.
#     </div>
# </div>

# %%
info_box("""
    <b>Python Script</b>
    <p>This is the import info_box</p>
""")
# Out:
#     <div style="
#         border: 2px solid #28a745;
#         border-radius: 8px;
#         padding: 20px;
#         margin: 10px 0;
#         background-color: #f8fff9;
#         position: relative;
#         max-width: 100%;
#         box-sizing: border-box;
#     ">
#         <div style="
#             position: absolute;
#             top: -12px;
#             left: 15px;
#             background-color: #28a745;
#             color: white;
#             width: 24px;
#             height: 24px;
#             border-radius: 50%;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-family: serif;
#             font-weight: bold;
#             font-style: italic;
#         ">i</div>
#         <div style="color: #155724; font-size: 1.1em; line-height: 1.5;">
#
#     <b>Python Script</b>
#     <p>This is the import info_box</p>
#
#         </div>
#     </div>

# %% [markdown]
# <div class="info-box">
#     <div class="info-box-badge">i</div>
#     <b>My Title</b>
#     <p>My content here...</p>
# </div>

# %% [markdown]
# <div class="info-box2">
#     <b>My Title</b>
#     <p>My content here...</p>
# </div>

# %% [markdown]
# Hier ghet es weiter mit [Part 2!](part2.ipynb)

# %% [markdown]
# <div class="next-button-container">
#     <a class="next-button" href="part2.ipynb">Next →</a>
# </div>
