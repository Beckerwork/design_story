# %%
import sys
import os

# %matplotlib widget
from IPython.display import display, HTML
sys.path.append(os.path.abspath("src"))
from regression.linear_regression import plot_data, lineare_regression, lineare_regression_big

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Im Serverraum</h2>
#   <p>
# Der Code funktioniert. Mit einem leisen Klicken öffnet sich die schwere Tür.
#
# Was ihr seht, verschlägt euch den Atem.
#
# Reihe um Reihe von deckenhohen Serverschränken, alle schwach blau leuchtend, ein leises Summen in der Luft. Die Wände sind bedeckt mit Bildschirmen voller Datenströme – Namen, Zahlen, Profile, Verbindungslinien zwischen Millionen von Punkten.
#
# **Sarah** flüstert: „Das sind... Menschen. Das sind Profile von echten Menschen."
#
# **Beep** scannt die nächsten Bildschirme: „Bestätigt. Ich erkenne Bewegungsprofile, Kaufverhalten, Schlafrhythmen, soziale Verbindungen—"
#
# Dann: Ein grelles Rot. Ein durchdringender Alarm.
#
# **UNBEFUGTER ZUGANG – ZONE SERVERRAUM – SICHERHEITSPROTOKOLL AKTIV.**
#
# **Ben:** „Rennt!"
#
# Doch bevor ihr auch nur drei Schritte macht, öffnen sich am anderen Ende des Serverraums zwei große Schwingtüren – und herein rollen vier Sicherheitsroboter. Kompakt, schnell, mit roten Sensorleuchten, die sich sofort auf euch richten.
#
# **Sarah:** „Woher wissen die so schnell, wo wir sind?!"
#
# **Beep:** „Sie analysieren gerade eure biometrischen Daten. Körpergröße, Schrittfrequenz – sie berechnen, wie schnell ihr seid. Und sie richten ihre eigene Geschwindigkeit danach aus."
#
# **Ben:** „Was?! Die wissen, wie schnell wir rennen können?"
#
# **Beep:** „Sie schätzen es. Basierend auf eurer Körpergröße und einem Datensatz, den sie über Kinder gespeichert haben."
#
# Ihr rennt. Links, rechts, durch Serverreihen, Beep flitzt hinterher. Hinter einer letzten Reihe von Serverschränken entdeckt ihr eine kleine Nebentür, kaum sichtbar zwischen den Schränken. Beep drückt im Vorbeilaufen seine Sensoren kurz an ein Terminal – ein leises Piepen – dann reißt ihr die Tür auf, springt hindurch und drückt sie hinter euch zu.
#
# Stille.
#
# Atemlos lehnt ihr euch gegen die Wand. Der Raum ist klein, vollgestellt mit alten Gerätschaften und Kabeln. Durch die Wände hört ihr die Roboter vorbeifahren – aber sie scheinen euch nicht entdeckt zu haben.
#
# **Ben** keucht: „Was war das eben? Wie können die wissen, wie schnell wir sind?"
#
# **Beep** öffnet ein Hologramm in der Luft vor euch. „Ich habe beim Vorbeilaufen einen Datensatz kopiert. Schaut her." Blaue Punkte erscheinen – eine Achse für Körpergröße, eine für Laufgeschwindigkeit.
#   </p>
# </div>

# %%
plot_data()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Die Regressionsgerade</h2>
#   <p>
# **Sarah** beugt sich vor. „Jeder Punkt ist ein Kind?"
#
# **Beep:** „Genau. TecVille hat von Kindern zwei Dinge gemessen: die Körpergröße und die maximale Laufgeschwindigkeit. Wahrscheinlich heimlich, über BuddyBot."
#
# **Ben** nickt langsam. „Und mit diesen Punkten... kann man eine Gerade einzeichnen. Eine Linie, die möglichst nah an allen Punkten liegt."
#
# **Beep:** „Richtig. Diese Gerade nennt man Regressionsgerade. Sobald sie einmal berechnet ist, kann man für jede beliebige Körpergröße ablesen, wie schnell jemand voraussichtlich läuft – auch für Größen, die gar nicht im Datensatz stehen."
#
# **Sarah:** „Zum Beispiel ich. Ich bin 145 cm. Da gibt es keinen Punkt."
#
# **Beep:** „Aber es gibt eine Gerade. Und die macht trotzdem eine Vorhersage."
#
# **Ben:** „Dann lass uns selbst mal versuchen, diese Gerade zu finden. Wie gut sind wir darin, die Roboter nachzuahmen?""
#   </p>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-pencil"></i>
#   </span>
#   <h3>Aufgabe 2.1 – Regressionsgerade erstellen</h3>
#   <p>
# Verändere die Steigung und den y-Achsenabschnitt deiner Geraden so, dass die Gerade möglichst nah an allen Datenpunkten liegt. Je kleiner der Fehlerwert, desto besser. Die Gerade der Roboter kannst du durch einen Klick auf „Zeige Regressionsgerade" anzeigen lassen – aber nur, wenn deine Gerade schon gut genug ist!
#   </p>
# </div>

# %%
lineare_regression()
# Out:
# interactive(children=(FloatSlider(value=0.05, description='Steigung', max=0.3, min=0.05, step=0.01), FloatSlid…
# Checkbox(value=False, description='Zeige Regressionsgerade', indent=False)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lineare_regression_big()
# Out:
# interactive(children=(FloatSlider(value=0.1, description='Steigung', max=0.4, min=0.1, step=0.01), FloatSlider…
# Checkbox(value=False, description='Zeige Regressionsgerade', indent=False)
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-pencil"></i>
#   </span>
#   <h3>Aufgabe 2.2 – Regressionsgerade benutzen</h3>
#   <p>
# Was glauben die Maschinen, wie schnell Sarah ist? Benutze die Gerade der Roboter, um es herauszufinden!
#   </p>
# </div>

# %%
with open("src/widgets/guess_speed.html", "r") as f: display(HTML(f.read()))
# Out:
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f; max-width: 420px; margin-left: auto; margin-right: auto;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-lock"></i>
#   </span>
#   <div style="text-align:center; margin-bottom:16px;">
#     <h3 style="color:#31708f; margin:0 0 6px 0;">🤖 Maschinenvorhersage</h3>
#     <p style="margin:0; color:#31708f; font-size:14px;">
#       Wie schnell ist Sarah?
#     </p>
#   </div>
#   <hr style="border:none; border-top:1px solid #31708f; opacity:0.3; margin-bottom:16px;">
#   <div style="display:flex; flex-direction:column; align-items:center; gap:10px;">
# ...
