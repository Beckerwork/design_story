# %% [markdown]
# # Bootstrap Test — no imports
#
# > ⚠️ This only works in **classic Jupyter Notebook**, not JupyterLab. Bootstrap is built into classic Notebook but not Lab.

# %% [markdown]
# <div class="alert alert-success">
#   <strong>Success (alert-success)</strong> — This is a green info box.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <strong>Info (alert-info)</strong> — This is a blue exercise box.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>Warning (alert-warning)</strong> — This is a yellow hint box.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>Danger (alert-danger)</strong> — This is a red warning box.
# </div>
