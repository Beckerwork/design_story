# %% [markdown]
# # Header

# %%
from styles import load_styles, load_styles2, info_box
load_styles()
load_styles2()
# Out:
#     <style>
#     .info-box {
#         border: 2px solid #28a745;
#         border-radius: 8px;
#         padding: 20px;
#         margin: 10px 0;
#         background-color: #f8fff9;
#         position: relative;
#         max-width: 100%;
#         box-sizing: border-box;
#         color: #155724;
#         font-size: 1.1em;
#         line-height: 1.5;
#     }
#     .info-box-badge {
#         position: absolute;
#         top: -12px;
#         left: 15px;
#         background-color: #28a745;
#         color: white;
#         width: 24px;
#         height: 24px;
#         border-radius: 50%;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         font-family: serif;
#         font-weight: bold;
#         font-style: italic;
#         font-size: 1rem;
#     }
#     .next-button-container {
#         text-align: center;
#         margin-top: 20px;
#     }
#     .next-button {
#         display: inline-block;
# ...

# %%
# A quick test script for your Python environment
import sys

def test_environment():
    print("--- Python Test Output ---")
    
    # 1. Basic Math
    result = (10 * 5) + 2
    print(f"Math Check: (10 * 5) + 2 = {result}")

    # 2. System Version
    print(f"Python Version: {sys.version.split()[0]}")

    # 3. Loops and Lists
    fruits = ["Apple", "Banana", "Cherry"]
    print("Looping through a list:")
    for fruit in fruits:
        print(f" - Found: {fruit}")

    print("--------------------------")
    print("Test Complete: Everything is running smoothly!")

# Execute the function
test_environment()
# Out:
# --- Python Test Output ---
# Math Check: (10 * 5) + 2 = 52
# Python Version: 3.12.7
# Looping through a list:
#  - Found: Apple
#  - Found: Banana
#  - Found: Cherry
# --------------------------
# Test Complete: Everything is running smoothly!

# %% [markdown]
# <div style="
#     border: 2px solid #28a745;
#     border-radius: 8px;
#     padding: 20px;
#     margin: 10px 0;
#     background-color: #f8fff9;
#     position: relative;
#     max-width: 100%;
#     box-sizing: border-box;
# ">
#     <div style="
#         position: absolute;
#         top: -12px;
#         left: 15px;
#         background-color: #28a745;
#         color: white;
#         width: 24px;
#         height: 24px;
#         border-radius: 50%;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#         font-family: serif;
#         font-weight: bold;
#         font-style: italic;
#     ">
#         i
#     </div>
#     <div style="color: #155724; font-size: 1.1em; line-height: 1.5;">
#         <b>Just html, no bootstrap</b><br>
#         HTML needs to be repeated in every cell, not really clean. Works in VS Code.
#     </div>
# </div>

# %%
info_box("""
    <b>Python Script - works in vs code</b>
    <p>Little bit ugly since there has to be a code cell above...</p>
""")
# Out:
#     <div style="
#         border: 2px solid #28a745;
#         border-radius: 8px;
#         padding: 20px;
#         margin: 10px 0;
#         background-color: #f8fff9;
#         position: relative;
#         max-width: 100%;
#         box-sizing: border-box;
#     ">
#         <div style="
#             position: absolute;
#             top: -12px;
#             left: 15px;
#             background-color: #28a745;
#             color: white;
#             width: 24px;
#             height: 24px;
#             border-radius: 50%;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-family: serif;
#             font-weight: bold;
#             font-style: italic;
#         ">i</div>
#         <div style="color: #155724; font-size: 1.1em; line-height: 1.5;">
#
#     <b>Python Script - works in vs code</b>
#     <p>Little bit ugly since there has to be a code cell above...</p>
#
#         </div>
#     </div>

# %% [markdown]
# <div class="info-box">
#     <div class="info-box-badge">i</div>
#     <b>Created own style, loaded using python at the top!</b>
#     <p>Does not work in VS code</p>
# </div>

# %% [markdown]
# <div class="info-box2">
#     <b>Created own style, loaded using python at the top! Nested the "i" for brevity in this cell.</b>
#     <p>Does not work in VS Code.</p>
# </div>
