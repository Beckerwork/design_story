# %% [markdown]
# # Bootstrap Test — built-in vs not built-in
#
# The cells below use Bootstrap classes — no CDN import. Some will render, some won't.

# %% [markdown]
# ## ✅ Built into classic Jupyter Notebook

# %% [markdown]
# <div class="alert alert-success">
#   <strong>alert alert-success</strong> — should be green
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <strong>alert alert-info</strong> — should be blue
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>alert alert-warning</strong> — should be yellow
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>alert alert-danger</strong> — should be red
# </div>

# %% [markdown]
# ## ❓ Probably not built in (Bootstrap 4/5 classes)

# %% [markdown]
# <div class="card bg-dark text-white p-3 mb-2" style="border-radius: 8px;">
#   <strong>card bg-dark text-white</strong> — should be a dark card
# </div>

# %% [markdown]
# <div class="badge bg-primary p-2">
#   badge bg-primary — should be a blue badge
# </div>

# %% [markdown]
# <div class="d-flex gap-2">
#   <div class="bg-primary text-white p-2">box 1</div>
#   <div class="bg-secondary text-white p-2">box 2</div>
#   <div class="bg-success text-white p-2">box 3</div>
# </div>
# <p><small>d-flex gap-2 — should be three colored boxes side by side</small></p>

# %% [markdown]
# <div class="rounded-pill bg-info text-white p-2 text-center">
#   rounded-pill bg-info — should be a pill-shaped cyan box
# </div>

# %% [markdown]
# <div class="shadow-lg p-3 mb-2 bg-white">
#   shadow-lg — should have a large drop shadow
# </div>
