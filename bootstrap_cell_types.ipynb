# %% [markdown]
# # Part 3 | Bootstrap Cell Style Showcase - uses repeating html (bad for maintenance)
#
# This notebook demonstrates different cell styles you can use in your Jupyter notebooks. No bootstrap import, just uses bootstrap in here. Works in VS Code. Some html has to be repeated, no types were defined in another file, everything is here.

# %% [markdown]
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">

# %% [markdown]
# ---
# ## 📖 Story / Narrative Styles

# %% [markdown]
# ### Option A — Dark card with quote feel
#
# <div class="card text-white bg-dark mb-3" style="border-radius: 12px; border-left: 6px solid #f0ad4e;">
#   <div class="card-body" style="padding: 24px;">
#     <h5 class="card-title"><i class="fas fa-book-open me-2" style="color:#f0ad4e;"></i> The Story So Far</h5>
#     <p class="card-text" style="font-style: italic; line-height: 1.8;">
#       It was a dark and rainy evening when the data scientist opened her laptop. The dataset had 10,000 rows —
#       more than she had ever seen. She took a deep breath and typed the first line of code.
#     </p>
#     <p class="card-text" style="font-style: italic; line-height: 1.8;">
#       Little did she know, the journey had only just begun.
#     </p>
#   </div>
# </div>

# %% [markdown]
# ### Option B — Light parchment style
#
# <div style="
#     background-color: #fffdf3;
#     border-left: 5px solid #c8a951;
#     border-radius: 8px;
#     padding: 20px 28px;
#     margin: 10px 0;
#     font-family: Georgia, serif;
#     font-size: 1.05em;
#     line-height: 1.9;
#     color: #3d3320;
#     box-shadow: 2px 2px 8px rgba(0,0,0,0.07);
# ">
#   <span style="font-size:1.5em; float:left; margin-right:10px; color:#c8a951;">❝</span>
#   In the beginning, there was data. Raw, unstructured, and full of potential.
#   Our task is to make sense of it — one cell at a time.
#   <br><br>
#   The tools we build here will carry us through the chapters ahead.
# </div>

# %% [markdown]
# ### Option C — Bootstrap secondary alert (clean & minimal)
#
# <div class="alert alert-secondary" style="border-left: 5px solid #6c757d; border-radius: 8px; font-size: 1.05em; line-height: 1.8;">
#   <i class="fas fa-feather-alt me-2"></i>
#   <strong>Chapter 3:</strong> With the data cleaned and the model defined, it was time to train.
#   The loss curve crept downward with each epoch — slowly, then all at once.
# </div>

# %% [markdown]
# ---
# ## ✏️ Exercise Styles

# %% [markdown]
# ### Option A — Bootstrap blue alert (classic)
#
# <div class="alert alert-info" style="border-radius: 10px;">
#   <h4><i class="fa fa-laptop" style="font-size:24px;"></i> &nbsp; Exercise 1 — Explore the Dataset</h4>
#   <hr>
#   Use the code cell below to answer the following questions:
#   <ol style="margin-top: 10px;">
#     <li>How many rows and columns does the dataset have?</li>
#     <li>Are there any missing values?</li>
#     <li>What is the data type of each column?</li>
#   </ol>
#   <hr>
#   <i class="fas fa-wrench"></i> &nbsp; <strong>Tip:</strong> Try using <code>df.info()</code> and <code>df.isnull().sum()</code>.
# </div>

# %% [markdown]
# ### Option B — Custom styled with badge
#
# <div style="
#     border: 2px solid #0d6efd;
#     border-radius: 10px;
#     padding: 20px 24px;
#     margin: 10px 0;
#     background-color: #f0f6ff;
#     position: relative;
# ">
#   <div style="
#       position: absolute; top: -13px; left: 16px;
#       background-color: #0d6efd; color: white;
#       padding: 2px 14px; border-radius: 20px;
#       font-weight: bold; font-size: 0.85em;
#   ">✏️ Exercise 2</div>
#   <h5 style="margin-top: 6px; color: #0d3080;">Write a function</h5>
#   <p>Write a Python function called <code>normalize(values)</code> that takes a list of numbers and scales them to the range [0, 1].</p>
#   <p>Test it with the list: <code>[10, 20, 30, 40, 50]</code></p>
# </div>

# %% [markdown]
# ### Option C — Bootstrap warning (stands out on the page)
#
# <div class="alert alert-warning" style="border-radius: 10px;">
#   <h4><i class="fa fa-pencil-square-o"></i> &nbsp; Exercise 3 — Reflect</h4>
#   <p>Look at the two plots above and answer in the text cell below:</p>
#   <ul>
#     <li>What differences do you notice between the two distributions?</li>
#     <li>What might explain these differences?</li>
#   </ul>
# </div>

# %% [markdown]
# ---
# ## 💡 Hint Styles

# %% [markdown]
# ### Option A — Collapsible hint (click to reveal)
#
# <details style="
#     background-color: #f8f9fa;
#     border: 1px solid #ced4da;
#     border-radius: 8px;
#     padding: 12px 18px;
#     margin: 10px 0;
# ">
#   <summary style="cursor: pointer; font-weight: bold; color: #495057;">
#     <i class="fas fa-lightbulb" style="color: #ffc107;"></i> &nbsp; Show Hint
#   </summary>
#   <div style="margin-top: 12px; color: #495057; line-height: 1.7;">
#     Remember that normalization means mapping values to a fixed range.
#     The formula is: <code>(x - min) / (max - min)</code>.
#     <br>You can use Python's built-in <code>min()</code> and <code>max()</code> functions.
#   </div>
# </details>

# %% [markdown]
# ### Option B — Always visible, subtle style
#
# <div class="alert alert-success" style="border-radius: 10px; opacity: 0.85;">
#   <i class="fas fa-life-ring"></i> &nbsp; <strong>Hint:</strong> &nbsp;
#   Think about what happens when <code>x = min</code> and when <code>x = max</code>.
#   What values should those produce?
# </div>

# %% [markdown]
# ### Option C — Stepped hints (reveal one at a time)
#
# <details style="background:#fffdf0; border:1px solid #ffc107; border-radius:8px; padding:10px 16px; margin:6px 0;">
#   <summary style="cursor:pointer; font-weight:bold; color:#856404;">💡 Hint 1 — Where to start</summary>
#   <p style="margin-top:10px;">Start by figuring out the minimum and maximum of the list.</p>
# </details>
#
# <details style="background:#fffdf0; border:1px solid #ffc107; border-radius:8px; padding:10px 16px; margin:6px 0;">
#   <summary style="cursor:pointer; font-weight:bold; color:#856404;">💡 Hint 2 — The formula</summary>
#   <p style="margin-top:10px;">For each value <code>x</code>, compute: <code>(x - min) / (max - min)</code></p>
# </details>
#
# <details style="background:#fffdf0; border:1px solid #ffc107; border-radius:8px; padding:10px 16px; margin:6px 0;">
#   <summary style="cursor:pointer; font-weight:bold; color:#856404;">💡 Hint 3 — Almost there</summary>
#   <p style="margin-top:10px;">Use a list comprehension: <code>[(x - mn) / (mx - mn) for x in values]</code></p>
# </details>

# %% [markdown]
# ---
# ## 🔗 Navigation Button Styles

# %% [markdown]
# ### Option A — Simple centered button
#
# <div style="text-align: center; margin: 20px 0;">
#   <a href="part1.ipynb" style="
#       display: inline-block;
#       background-color: #0d6efd;
#       color: white;
#       padding: 12px 36px;
#       border-radius: 8px;
#       text-decoration: none;
#       font-weight: bold;
#       font-size: 1em;
#       box-shadow: 0 4px 10px rgba(13,110,253,0.3);
#   ">← Back to Part 1</a>
# </div>

# %% [markdown]
# ### Option B — Outlined button (matches your existing project style)
#
# <div style="text-align: center; margin: 20px 0;">
#   <a href="part1.ipynb" style="
#       display: inline-block;
#       background-color: #f8fff9;
#       color: #28a745;
#       padding: 10px 30px;
#       border-radius: 12px;
#       border: 2px solid #28a745;
#       text-decoration: none;
#       font-weight: bold;
#       font-size: 1em;
#       box-shadow: 0 4px 8px rgba(0,0,0,0.15);
#   ">← Back to Part 1</a>
# </div>

# %% [markdown]
# ### Option C — Full navigation bar (prev + next)
#
# <div style="display: flex; justify-content: space-between; margin: 20px 0;">
#   <a href="part1.ipynb" style="
#       display: inline-block;
#       background-color: #f8f9fa;
#       color: #495057;
#       padding: 10px 24px;
#       border-radius: 8px;
#       border: 1px solid #ced4da;
#       text-decoration: none;
#       font-weight: bold;
#   ">← Part 1</a>
#   <a href="part2.ipynb" style="
#       display: inline-block;
#       background-color: #0d6efd;
#       color: white;
#       padding: 10px 24px;
#       border-radius: 8px;
#       text-decoration: none;
#       font-weight: bold;
#   ">Part 2 →</a>
# </div>

# %% [markdown]
# ### Option D — Bootstrap pill badge style
#
# <div style="text-align: center; margin: 24px 0;">
#   <a href="part1.ipynb" class="badge" style="
#       background-color: #6f42c1;
#       color: white;
#       padding: 12px 28px;
#       border-radius: 50px;
#       text-decoration: none;
#       font-size: 1em;
#       font-weight: 600;
#       letter-spacing: 0.5px;
#       box-shadow: 0 4px 12px rgba(111,66,193,0.35);
#   ">🔗 &nbsp; Go to Part 1</a>
# </div>
