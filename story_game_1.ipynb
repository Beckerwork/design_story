# %%
from IPython.display import display, HTML

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Die Klassenfahrt nach TecVille</h2>
#
#   <!-- Paragraph 1 + city image side by side -->
#   <div style="display: flex; gap: 16px; align-items: flex-start; margin-bottom: 12px;">
#     <p style="margin: 0;">Wir schreiben das Jahr 2125. Menschen und Roboter leben seit Jahrzehnten friedlich zusammen. Roboter übernehmen gefährliche Arbeiten, pflegen Kranke und unterrichten in Schulen. Die Welt ist vernetzter denn je – und digitaler.</p>
#     <img src="src/images/1-city.webp" style="max-width: 220px; border-radius: 6px; flex-shrink: 0;">
#   </div>
#
#   <!-- Paragraph 2 + tecville image side by side -->
#   <div style="display: flex; gap: 16px; align-items: flex-start; margin-bottom: 12px;">
#     <p style="margin: 0;">Für deine Klasse steht heute ein besonderer Tag auf dem Programm: Klassenfahrt zu TecVille, dem größten Technologiekonzern der Welt. Jeder kennt TecVille. Ihre Apps sind überall: „Pulse" ist die beliebteste Social-Media-Plattform, „StreamZ" zeigt Filme und Serien, „BuddyChat" ist der persönliche KI-Assistent, den fast alle Kinder täglich nutzen. Kurz gesagt: TecVille ist aus dem Alltag nicht mehr wegzudenken.</p>
#     <img src="src/images/1-tecville.webp" style="max-width: 220px; border-radius: 6px; flex-shrink: 0;">
#   </div>
#
#   <!-- Paragraph 3 + 4 (no image) -->
#   <p>Das Firmengelände von TecVille ist gigantisch. Gläserne Türme ragen in den Himmel, zwischen den Gebäuden fahren lautlose Transportroboter hin und her. Ein freundlicher Roboter führt die Klasse durch beeindruckende Ausstellungsräume: holografische Interfaces, selbstlernende Systeme, neueste Hardwareentwicklungen.</p>
#   <p>An deiner Seite sind Sarah und Ben – deine besten Freunde. Und natürlich Beep, Sarahs kleiner Assistenzroboter, der ihr überallhin folgt. Sarah ist neugierig und abenteuerlustig, immer auf der Suche nach dem nächsten Rätsel. Ben ist nachdenklich und analytisch, der Typ, der sich immer fragt, warum etwas funktioniert – nicht nur, dass es funktioniert.</p>
#
#   <!-- Sarah, Beep, Ben in a flexbox row -->
#   <div style="display: flex; gap: 16px; justify-content: center; margin-top: 8px;">
#     <img src="src/images/1-sarah.webp" style="flex: 1; max-width: 33%; border-radius: 6px; object-fit: cover;">
#     <img src="src/images/1-beep.webp" style="flex: 1; max-width: 33%; border-radius: 6px; object-fit: cover;">
#     <img src="src/images/1-ben.webp" style="flex: 1; max-width: 33%; border-radius: 6px; object-fit: cover;">
#   </div>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Das Geheimnis von TecVille</h2>
#
#   <p>Während alle staunen und Fotos machen, grübelt Ben.</p>
#   <p><strong>Ben:</strong> „Ich verstehe das nicht. Pulse, StreamZ, BuddyChat – alle kostenlos. Wir zahlen nichts. Aber schau dir das hier an." Er zeigt auf die riesigen Gebäude um sie herum. „Das kostet Milliarden. Woher kommt das Geld?"</p>
#   <p><strong>Sarah</strong> zuckt die Schultern: „Keine Ahnung. Vielleicht Werbung?"</p>
#   <p><strong>Ben:</strong> „Werbung allein reicht dafür nicht. Da steckt mehr dahinter."</p>
#   <p><strong>Beep</strong> surrt leise: „Laut meinen Daten erwirtschaftet TecVille einen Großteil seines Umsatzes durch den Verkauf von Nutzeranalysen an andere Unternehmen. Was genau sie analysieren, ist jedoch nicht öffentlich bekannt."</p>
#   <p>Eine kurze Stille.</p>
#   <p><strong>Sarah</strong> grinst: „Dann finden wir es eben heraus."</p>
#
#   <hr>
#
#   <p>Die Gruppe geht in eine große Präsentationshalle für eine Vorführung. Die Lichter dimmen, eine Bühnenshow beginnt – perfekter Moment.</p>
#   <p>„Jetzt oder nie", flüstert <strong>Sarah</strong>.</p>
#   <p>Ihr drei schleicht euch lautlos aus der Halle. Die Gänge dahinter sind menschenleer, nur gelegentlich gleitet ein Serviceroboter vorbei. Beep navigiert euch anhand seines internen Gebäudeplans tiefer ins Firmeninnere. Nach mehreren Abzweigungen bleibt er vor einer unscheinbaren Metalltür stehen.</p>
#
#   <!-- Last block: text left, image right -->
#   <div style="display: flex; gap: 16px; align-items: flex-start;">
#     <div>
#       <p style="margin-top: 0;"><strong>Beep:</strong> „Laut Grundriss: Serverraum. Hier werden alle Nutzerdaten von TecVille gespeichert und verarbeitet."</p>
#       <p>Ben und Sarah tauschen einen Blick aus.</p>
#       <p>Die Tür hat ein digitales Schloss. Doch direkt daneben liegt ein Papierstapel auf dem Boden – zerknüllte, zerrissene Zettel, als hätte jemand sie hastig weggeworfen. Ben hebt einen auf. Dann noch einen.</p>
#       <p><strong>Ben:</strong> „Warte mal... auf diesem hier steht 'SERVER'. Und auf dem: 'ZUGANG'. Das sind Teile eines Codes."</p>
#     </div>
#     <img src="src/images/1-zettel.webp" style="max-width: 220px; border-radius: 6px; flex-shrink: 0;">
#   </div>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-pencil"></i>
#   </span>
#   <h3>Aufgabe: Puzzle</h3>
#   <p>
# Nimm den Umschlag und probiere durch das Puzzle das Passwort für den Serverraum herauszubekommen.
#   </p>
# </div>

# %%
with open("src/widgets/find_password.html", "r") as f: display(HTML(f.read()))
# Out:
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 32px 20px 32px; margin-top: 25px; border: 4px solid #31708f; max-width: 420px; margin-left: auto; margin-right: auto;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-lock"></i>
#   </span>
#   <div style="text-align:center; margin-bottom:16px;">
#     <h3 style="color:#31708f; margin:0 0 6px 0;">🔐 Zugang zum Serverraum</h3>
#     <p style="margin:0; color:#31708f; font-size:14px;">
#       Gebt das Codewort ein, um die Tür zu öffnen:
#     </p>
#   </div>
#   <hr style="border:none; border-top:1px solid #31708f; opacity:0.3; margin-bottom:16px;">
#   <div style="display:flex; flex-direction:column; align-items:center; gap:10px;">
# ...
