# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h3>Die Klassenfahrt nach TecVille</h3>
#       <p>
# Wir schreiben das Jahr 2125. Menschen und Roboter leben seit Jahrzehnten friedlich zusammen. Roboter übernehmen gefährliche Arbeiten, pflegen Kranke und unterrichten in Schulen. Die Welt ist vernetzter denn je – und digitaler.
#
# Das Firmengelände von NexusCore ist gigantisch. Gläserne Türme ragen in den Himmel, zwischen den Gebäuden fahren lautlose Transportroboter hin und her. Euer Guide, ein freundlicher Roboter namens Vex, führt die Klasse durch beeindruckende Ausstellungsräume: holografische Interfaces, selbstlernende Systeme, neueste Hardwareentwicklungen.
#
# Für deine Klasse steht heute ein besonderer Tag auf dem Programm: Klassenfahrt zu NexusCore, dem größten Technologiekonzern der Welt. Jeder kennt NexusCore. Ihre Apps sind überall: „Pulse" ist die beliebteste Social-Media-Plattform, „StreamZ" zeigt Filme und Serien, „BuddyBot" ist der persönliche KI-Assistent, den fast alle Kinder täglich nutzen. Kurz gesagt: NexusCore ist aus dem Alltag nicht mehr wegzudenken.
#       </p>
#   <div style="display: flex; justify-content: center; gap: 20px; margin: 20px 0; flex-wrap: wrap;">
#     <div style="text-align: center; flex: 1; max-width: 200px;">
#       <p style="text-align: center;">City</p>
#       <img src="images/ml_intro/city.jpg" style="width: 100%; height: auto; border-radius: 8px;">
#     </div>
#     <div style="text-align: center; flex: 1; max-width: 200px;">
#       <p style="text-align: center;">Tecville</p>
#       <img src="images/ml_intro/Tecville.jpg" style="width: 100%; height: auto; border-radius: 8px;">
#     </div>
#   </div>
#   <hr>
#   <p>
# An deiner Seite sind Sarah und Ben – deine besten Freunde. Und natürlich Beep, Sarahs kleiner Assistenzroboter, der ihr überallhin folgt. Sarah ist neugierig und abenteuerlustig, immer auf der Suche nach dem nächsten Rätsel. Ben ist nachdenklich und analytisch, der Typ, der sich immer fragt, warum etwas funktioniert – nicht nur, dass es funktioniert.
#   </p>
#   <div style="display: flex; justify-content: center; gap: 20px; margin: 20px 0; flex-wrap: wrap;">
#     <div style="text-align: center; flex: 1; max-width: 200px;">
#       <p style="text-align: center;">Sarah</p>
#       <img src="images/ml_intro/Sarah.jpg" style="width: 100%; height: auto; border-radius: 8px;">
#     </div>
#     <div style="text-align: center; flex: 1; max-width: 200px;">
#       <p style="text-align: center;">Beep</p>
#       <img src="images/ml_intro/Beep.jpg" style="width: 100%; height: auto; border-radius: 8px;">
#     </div>
#     <div style="text-align: center; flex: 1; max-width: 200px;">
#       <p style="text-align: center;">Ben</p>
#       <img src="images/ml_intro/Ben.jpg" style="width: 100%; height: auto; border-radius: 8px;">
#     </div>
#   </div>
#   <hr>
#   <p>
# Während alle staunen und Fotos machen, grübelt Ben.
#
# **Ben:** „Ich versteh das nicht. Pulse, StreamZ, BuddyBot – alle kostenlos. Wir zahlen nichts. Aber schau dir das hier an." Er zeigt auf die riesigen Gebäude um sie herum. „Das kostet Milliarden. Woher kommt das Geld?"
#
# **Sarah** zuckt die Schultern: „Keine Ahnung. Vielleicht Werbung?"
#
# **Ben:** „Für Werbung allein reicht das nicht. Da steckt mehr dahinter."
#
# **Beep** surrt leise: „Laut meinen Daten erwirtschaftet NexusCore einen Großteil seines Umsatzes durch den Verkauf von Nutzeranalysen an andere Unternehmen. Was genau sie analysieren, ist jedoch nicht öffentlich bekannt."
#
# Eine kurze Stille.
#
# **Sarah** grinst: „Dann finden wir es eben heraus."
#
# ---
#
# Vex führt die Gruppe in eine große Präsentationshalle für eine Vorführung. Die Lichter dimmen, eine Bühnenshow beginnt – perfekter Moment.
#
# „Jetzt oder nie", flüstert Sarah.
#
# Ihr drei schleicht euch lautlos aus der Halle. Die Gänge dahinter sind menschenleer, nur gelegentlich gleitet ein Serviceroboter vorbei. Beep navigiert euch anhand seines internen Gebäudeplans tiefer ins Firmeninnere. Nach mehreren Abzweigungen bleibt er vor einer unscheinbaren Metalltür stehen.
#
# **Beep:** „Laut Grundriss: Serverraum. Hier werden alle Nutzerdaten von NexusCore gespeichert und verarbeitet."
#
# Ben und Sarah tauschen einen Blick aus.
#
# Die Tür hat ein digitales Schloss. Doch direkt daneben liegt ein Papierstapel auf dem Boden – zerknüllte, zerrissene Zettel, als hätte jemand sie hastig weggeworfen. Ben hebt einen auf. Dann noch einen.
#
# **Ben:** „Warte mal... auf diesem hier steht ‚SERVER'. Und auf dem: ‚ZUGANG'. Das sind Teile eines Codes."
#
# Ihr sammelt alle Schnipsel auf und breitet sie auf dem Boden aus.
#   </p>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-pencil"></i>
#   </span>
#   <h3>Aufgabe: Puzzle</h3>
# Nimm den Umschlag und probiere das durch das Puzzle das Passwort für den Serverraum herauszubekommen.
# </div>

# %%
import sys
import os

# %matplotlib widget

sys.path.append(os.path.abspath("src"))
from regression.password3 import password3
password3()
# Out:
#     <style>
#     .pw-box {
#         background-color: #beeaf1 !important;
#         border: 4px solid #31708f !important;
#         border-radius: 10px !important;
#         padding: 24px 32px 20px 32px !important;
#         max-width: 420px !important;
#         margin: 25px auto 0 auto !important;
#     }
#     .pw-box .widget-label {
#         display: none !important;
#     }
#     .pw-field input, .pw-text input {
#         border: 1.5px solid #31708f !important;
#         border-radius: 6px !important;
#         padding: 7px 12px !important;
#         font-size: 14px !important;
#         background: white !important;
#         outline: none !important;
#         width: 100% !important;
#     }
#     .pw-field input:focus, .pw-text input:focus {
#         box-shadow: 0 0 0 3px rgba(49,112,143,0.2) !important;
#     }
#     .pw-btn button {
#         background-color: #31708f !important;
#         color: white !important;
#         border: none !important;
# ...
