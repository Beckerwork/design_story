# %%
import sys
import os

# %matplotlib widget
from IPython.display import display, HTML
sys.path.append(os.path.abspath("src"))
from regression.linear_regression import plot_data, lineare_regression_big

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Im Serverraum</h2>
#
#   <div style="display: flex; gap: 16px; align-items: flex-start;">
#     <div>
#       <p style="margin-top: 0;">Der Code funktioniert. Mit einem leisen Klicken öffnet sich die schwere Tür.</p>
#       <p>Was ihr seht, verschlägt euch den Atem.</p>
#       <p>Reihe um Reihe von deckenhohen Serverschränken, alle schwach blau leuchtend, ein leises Summen in der Luft. Die Wände sind bedeckt mit Bildschirmen voller Datenströme – Namen, Zahlen, Profile, Verbindungslinien zwischen Millionen von Punkten.</p>
#       <p><strong>Sarah</strong> flüstert: „Das sind... Menschen. Das sind Profile von echten Menschen."</p>
#       <p><strong>Beep</strong> scannt die nächsten Bildschirme: „Bestätigt. Ich erkenne Bewegungsprofile, Kaufverhalten, Schlafrhythmen, soziale Verbindungen—" Beep kann seinen Satz nicht beenden.</p>
#     </div>
#     <img src="src/images/2-serverraum.jpg" style="max-width: 220px; border-radius: 6px; flex-shrink: 0;">
#   </div>
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #a94442;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #a94442; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-exclamation"></i>
#   </span>
#   <h3>Warnung im Serverraum</h3>
#
#   Lautsprecher ertönen: **„UNBEFUGTER ZUGANG – ZONE SERVERRAUM – SICHERHEITSROBOTER AKTIVIERT."**
#
# Ein grelles Rot. Ein durchdringender Alarm.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Im Serverraum</h2>
#
#   <!-- Text + alarm-2.jpg side by side, until first --- -->
#   <div style="display: flex; gap: 16px; align-items: flex-start;">
#     <div>
#       <p style="margin-top: 0;"><strong>Ben:</strong> „Rennt!"</p>
#       <p>Doch bevor ihr auch nur drei Schritte macht, öffnen sich am anderen Ende des Serverraums zwei große Schwingtüren – und herein rollen vier Sicherheitsroboter. Kompakt, schnell, mit roten Sensorleuchten, die sich sofort auf euch richten.</p>
#       <p><strong>Sarah:</strong> „Woher wissen die so schnell, wo wir sind?!"</p>
#       <p><strong>Beep:</strong> „Sie analysieren gerade eure biometrischen Daten. Körpergröße, Schrittfrequenz – sie berechnen, wie schnell ihr seid. Und sie richten ihre eigene Geschwindigkeit danach aus."</p>
#       <p><strong>Ben:</strong> „Was?! Die wissen, wie schnell wir rennen können?"</p>
#       <p><strong>Beep:</strong> „Sie schätzen es. Basierend auf eurer Körpergröße und einem Datensatz, den sie über Kinder gespeichert haben. Ich weiß, wo wir uns verstecken können! Mir nach!"</p>
#     </div>
#     <img src="src/images/2-alarm.jpg" style="max-width: 300px; border-radius: 6px; flex-shrink: 0;">
#   </div>
#
#   <hr>
#
#   <p>Ihr rennt. Links, rechts, durch Serverreihen, Beep flitzt voraus. Hinter einer letzten Reihe von Serverschränken entdeckt ihr eine kleine Nebentür, kaum sichtbar zwischen den Schränken. Ihr reißt die Tür auf, springt hindurch und drückt sie hinter euch zu.</p>
#   <p>Stille.</p>
#   <p>Atemlos lehnt ihr euch gegen die Wand. Der Raum ist klein, vollgestellt mit alten Gerätschaften und Kabeln. Durch die Wände hört ihr die Roboter vorbeifahren – aber sie scheinen euch nicht entdeckt zu haben.</p>
#
#   <hr>
#
#   <p><strong>Ben</strong> keucht: „Was war das eben? Wie können die wissen, wie schnell wir sind?"</p>
#   <p><strong>Beep</strong> öffnet ein Hologramm in der Luft vor euch. „Ich habe vorhin beim Vorbeilaufen einen Datensatz kopiert. Schaut her." Blaue Punkte erscheinen – eine Achse für Körpergröße, eine für Laufgeschwindigkeit.</p>
# </div>

# %%
plot_data()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Die Regressionsgerade</h2>
#
#   <img src="src/images/2-datenpunkte.jpg" style="float: right; margin-left: 16px; margin-bottom: 8px; max-width: 300px; border-radius: 6px;">
#
#   <p><strong>Sarah</strong> beugt sich vor. „Jeder Punkt da oben ist ein Kind?"</p>
#   <p><strong>Beep:</strong> „Genau. TecVille hat von Kindern zwei Dinge gemessen: die Körpergröße und die maximale Laufgeschwindigkeit. Wahrscheinlich heimlich, über BuddyChat."</p>
#   <p><strong>Ben:</strong> „Aber was machen die Roboter damit? Wie hilft ihnen das, unsere Geschwindigkeit vorherzusagen?"</p>
#   <p><strong>Beep:</strong> „Sie legen eine Gerade durch die Punkte – eine Linie, die möglichst nah an allen Datenpunkten liegt. Damit können sie für jede beliebige Körpergröße eine Geschwindigkeit vorhersagen, auch wenn diese Größe gar nicht im Datensatz vorkommt."</p>
#   <p><strong>Sarah:</strong> „Zum Beispiel ich. Ich bin 145 cm. Da gibt es keinen Punkt."</p>
#   <p><strong>Beep:</strong> „Genau. Aber so eine Gerade läuft trotzdem durch diesen Bereich – und macht eine Vorhersage. Das nennt man Regressionsgerade."</p>
#
#   <div style="clear: both;"></div>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-pencil"></i>
#   </span>
#   <h3>Aufgabe 2.1 – Regressionsgerade erstellen</h3>
#   <p><strong>Ben:</strong> „Dann lass uns selbst mal versuchen, diese Gerade zu finden. Vielleicht können wir die Roboter irgendwie austricksen."</p>
#
# ---
#
#   <p>Verändere die Steigung und den y-Achsenabschnitt deiner Geraden so, dass die Gerade möglichst nah an allen Datenpunkten liegt. Je kleiner der Fehlerwert, desto besser.
#
# Die Gerade der Roboter kannst du zum Vergleich durch einen Klick auf „Zeige Regressionsgerade" anzeigen lassen – aber nur, wenn deine Gerade schon genau genug ist!
#   </p>
# </div>

# %%
lineare_regression_big()
# Out:
# interactive(children=(FloatSlider(value=0.1, description='Steigung', max=0.4, min=0.1, step=0.01), FloatSlider…
# Checkbox(value=False, description='Zeige Regressionsgerade', indent=False)
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %% [markdown]
# <details style="background:#fffdf0; border:1px solid #ffc107; border-radius:8px; padding:10px 16px; margin:6px 0;">
#   <summary style="cursor:pointer; font-weight:bold; color:#856404;">💡 Was ist der Fehlerwert?</summary>
#   <p style="margin-top:10px; color:black;">Der Fehlerwert zeigt, wie weit die Datenpunkte im Durchschnitt von der Geraden entfernt sind. Je kleiner der Wert, desto besser passt die Gerade zu den Daten und desto präziser sind die Vorhersagen.</p>
# </details>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-pencil"></i>
#   </span>
#   <h3>Aufgabe 2.2 – Regressionsgerade benutzen</h3>
#   <p><strong>Sarah:</strong>„Können wir jetzt herausfinden, wie schnell ich laut den Robotern bin?</p>
#   <p><strong>Beep:</strong> „Das sollte gehen! Wenn ihr auf den Graphen tippt, werden die dazugehörigen (x,y)-Koordinaten unten angezeigt."</p>
#
# </div>

# %%
with open("src/widgets/guess_speed.html", "r") as f: display(HTML(f.read()))
# Out:
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f; max-width: 420px; margin-left: auto; margin-right: auto;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-lock"></i>
#   </span>
#   <div style="text-align:center; margin-bottom:16px;">
#     <h3 style="color:#31708f; margin:0 0 6px 0;">🤖 Maschinenvorhersage</h3>
#     <p style="margin:0; color:#31708f; font-size:14px;">
#       Wie schnell ist Sarah?
#     </p>
#   </div>
#   <hr style="border:none; border-top:1px solid #31708f; opacity:0.3; margin-bottom:16px;">
#   <div style="display:flex; flex-direction:column; align-items:center; gap:10px;">
# ...
