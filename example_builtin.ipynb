# %% [markdown]
# # Example Notebook — built-in Bootstrap & Font Awesome
# No imports needed. Works in classic Jupyter Notebook out of the box.

# %% [markdown]
# <div class="alert alert-success">
#   <h4><i class="fas fa-info" style="font-size: 24px;"></i> &nbsp; Information</h4>
#   This is a <strong>story / info box</strong>. Use it for background reading or explanations.
#   <br><br>
#   Lorem ipsum dolor sit amet, consectetur adipiscing elit. Pellentesque habitant morbi tristique senectus.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h4><i class="fa fa-laptop" style="font-size: 24px;"></i> &nbsp; Exercise 1 — Write a function</h4>
#   <hr>
#   Write a Python function called <code>normalize(values)</code> that rescales a list to [0, 1].
#   <br><br>
#   Test it with: <code>[10, 20, 30, 40, 50]</code><br>
#   Expected output: <code>[0.0, 0.25, 0.5, 0.75, 1.0]</code>
#   <hr>
#   <i class="fas fa-wrench"></i> &nbsp; <strong>Tip:</strong> Use Python's built-in <code>min()</code> and <code>max()</code>.
# </div>

# %% [markdown]
# <details>
# <summary><i class="fas fa-life-ring"></i> &nbsp; <strong>Show Hint</strong></summary>
# <br>
# <div class="alert alert-warning">
#   <i class="fas fa-info-circle"></i> &nbsp;
#   The formula is: <code>(x - min) / (max - min)</code>
#   <br><br>
#   Try using a list comprehension: <code>[(x - mn) / (mx - mn) for x in values]</code>
# </div>
# </details>

# %% [markdown]
# <div style="text-align: center; margin: 20px 0;">
#   <a href="part1.ipynb" style="
#     display: inline-block;
#     margin: 4px;
#     padding: 10px 28px;
#     border: 2px solid #337ab7;
#     border-radius: 8px;
#     color: #337ab7;
#     background-color: white;
#     text-decoration: none;
#     font-weight: bold;
#   ">← Part 1</a>
#   <a href="part3.ipynb" style="
#     display: inline-block;
#     margin: 4px;
#     padding: 10px 28px;
#     border: 2px solid #337ab7;
#     border-radius: 8px;
#     color: white;
#     background-color: #337ab7;
#     text-decoration: none;
#     font-weight: bold;
#   ">Part 3 →</a>
# </div>
